# %% [markdown]
# <a href="https://colab.research.google.com/github/PrabodaSankalpa/shramikaya/blob/main/Topic_6_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Mobile_Price_Classification-220531-204702.csv')

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X = data.drop('price_range', axis=1)
y = data['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 2ms/step - loss: 81.0694 - accuracy: 0.4973
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 38.6129 - accuracy: 0.5240
# Epoch 3/100
# 47/47 [==============================] - 0s 2ms/step - loss: 23.3620 - accuracy: 0.5687
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 11.6698 - accuracy: 0.6120
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 6.0562 - accuracy: 0.6067
# Epoch 6/100
# 47/47 [==============================] - 0s 2ms/step - loss: 3.7257 - accuracy: 0.5633
# Epoch 7/100
# 47/47 [==============================] - 0s 2ms/step - loss: 2.4339 - accuracy: 0.5393
# Epoch 8/100
# 47/47 [==============================] - 0s 2ms/step - loss: 1.2101 - accuracy: 0.5253
# Epoch 9/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.9327 - accuracy: 0.5153
# Epoch 10/100
# ...

# %%
model.save_weights('mobile_price_prediction_weights.h5')
